# %% [markdown]
# Importing Relevant Libraries:

# %%
# !pip install --upgrade gensim
from gensim.models import Word2Vec
import pandas as pd
import nltk
nltk.download('punkt')
import numpy as np
import re
# Out:
# Requirement already up-to-date: gensim in /usr/local/lib/python3.6/dist-packages (3.8.3)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (2.2.0)
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.18.5)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (2.23.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (2.10)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Importing data:

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f278c958-c963-4781-87ec-5ee11889384a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f278c958-c963-4781-87ec-5ee11889384a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ONGO.csv to ONGO (3).csv

# %%
import io
data_ongo = pd.read_csv(io.BytesIO(uploaded['ONGO.csv']))

# %%
data_ongo['source'] = 'ongo'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f9cfec15-27e6-42ce-93a8-d9980302f5f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f9cfec15-27e6-42ce-93a8-d9980302f5f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tweet.csv to tweet (3).csv

# %%
import io
data_tweet = pd.read_csv(io.BytesIO(uploaded['tweet.csv']))

# %%
data_tweet['source'] = 'tweet'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6224c24c-4304-4f35-a428-11e937c9cf01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6224c24c-4304-4f35-a428-11e937c9cf01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving reddit.csv to reddit (2).csv

# %%
import io
data_reddit = pd.read_csv(io.BytesIO(uploaded['reddit.csv']))

# %%
data_reddit['source']='reddit'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-10a7e861-e314-41a4-908c-72da5fe1a642" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10a7e861-e314-41a4-908c-72da5fe1a642">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.csv to kaggle (2).csv

# %%
import io
data_kaggle = pd.read_csv(io.BytesIO(uploaded['kaggle.csv']))

# %%
data_kaggle['source'] = 'kaggle'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e56aff99-9b7e-41f6-9f62-99f44f2f2b6f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e56aff99-9b7e-41f6-9f62-99f44f2f2b6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving evaluation_API_2.csv to evaluation_API_2 (1).csv

# %%
import io
data_youtube = pd.read_csv(io.BytesIO(uploaded['evaluation_API_2.csv']),sep=",", header=None)

# %%
data_youtube['source']='youtube'
data_youtube.columns = ["text", "extra", "source"]
data_youtube
# Out:
#                                                   text extra   source
# 0    First Class with you, Very good session👏.. Bea...   NaN  youtube
# 1          Wonderful practice. You are a great teacher   NaN  youtube
# 2                                       tq so much sir   NaN  youtube
# 3    Thanks jai master for giving such a wonderful ...   NaN  youtube
# 4                                     Thank u namaste🙏   NaN  youtube
# ..                                                 ...   ...      ...
# 399  fuck you you pussy ass hater go suck a dick an...   NaN  youtube
# 400  Send those illegal asshole crazy muslims, wetb...   NaN  youtube
# 401                          common girl suck my dick.   NaN  youtube
# 402  did your mama move like this before she was ra...   NaN  youtube
# 403              shut your mouth and just suck my dick   NaN  youtube
#
# [404 rows x 3 columns]

# %%
df = pd.concat([data_ongo, data_tweet, data_reddit, data_kaggle, data_youtube])

# %%
df
# Out:
#                                                   text   source  ...  ok  extra
# 0                                               Hello!     ongo  ... NaN    NaN
# 1                                Gotta get those zzzs!     ongo  ... NaN    NaN
# 2                                                  go!     ongo  ... NaN    NaN
# 3                                           go ongo go     ongo  ... NaN    NaN
# 4    Hey, can't wait to release the new version. Ne...     ongo  ... NaN    NaN
# ..                                                 ...      ...  ...  ..    ...
# 399  fuck you you pussy ass hater go suck a dick an...  youtube  ... NaN    NaN
# 400  Send those illegal asshole crazy muslims, wetb...  youtube  ... NaN    NaN
# 401                          common girl suck my dick.  youtube  ... NaN    NaN
# 402  did your mama move like this before she was ra...  youtube  ... NaN    NaN
# 403              shut your mouth and just suck my dick  youtube  ... NaN    NaN
#
# [227494 rows x 6 columns]

# %% [markdown]
# # Getting sense of data:

# %%
data_reddit.head(5)
# Out:
#                                                 text hate  ...  ok  source
# 0  go back to your castle you capitalist scum htt...    1  ...   0  reddit
# 1  i found her here http perfectredheads tumblr c...    1  ...   0  reddit
# 2  this slut gonna fuck with all http righpatcour...    1  ...   0  reddit
# 3  this girl gonna go into on your knees open her...    1  ...   0  reddit
# 4  attention reddit mods http www youtube com wat...    1  ...   0  reddit
#
# [5 rows x 5 columns]

# %%
data_tweet.head(5)
# Out:
#                                                 text  hate  ...  ok  source
# 0  !!! RT @mayasolovely: As a woman you shouldn't...     0  ...   1   tweet
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...     0  ...   0   tweet
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...     0  ...   0   tweet
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...     0  ...   0   tweet
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...     0  ...   0   tweet
#
# [5 rows x 5 columns]

# %%
data_ongo.head(5)
# Out:
#                                                 text source
# 0                                             Hello!   ongo
# 1                              Gotta get those zzzs!   ongo
# 2                                                go!   ongo
# 3                                         go ongo go   ongo
# 4  Hey, can't wait to release the new version. Ne...   ongo

# %%
data_kaggle.head(5)
# Out:
#                                                 text  hate  ...  ok  source
# 0  Explanation\nWhy the edits made under my usern...     0  ...   1  kaggle
# 1  D'aww! He matches this background colour I'm s...     0  ...   1  kaggle
# 2  Hey man, I'm really not trying to edit war. It...     0  ...   1  kaggle
# 3  "\nMore\nI can't make any real suggestions on ...     0  ...   1  kaggle
# 4  You, sir, are my hero. Any chance you remember...     0  ...   1  kaggle
#
# [5 rows x 5 columns]

# %% [markdown]
# # Tokenization using NLTK:

# %%
import re
def clean_text(text):
    #text = text.lower()
    text = re.sub(r"what's","what is", text)
    text = re.sub(r"rt", '',text)
    text = re.sub(r"\'ve","have", text)
    text = re.sub(r"can't","cannot",text)
    text = re.sub(r"n't", "not", text)
    text = re.sub(r"i'm","i am", text)
    text = re.sub(r"\'re'","are", text)
    text = re.sub(r"\'d'","would",text)
    text = re.sub(r"\'ll'", "will", text)
    text = re.sub(r"\'scuse'", "excuse", text)
    text = re.sub("\W",' ', text)
    text = re.sub('\s+',' ',text)
    text = text.strip(' ')
    text = re.sub(" \d+", " ", text)
    return text
#data_ongo['cmt'] = data_ongo['text'].map(lambda x: clean_text(x))
#data_reddit['cmt'] = data_reddit['text'].map(lambda x: clean_text(x))
#data_tweet['cmt'] = data_tweet['text'].map(lambda x: clean_text(x))
#data_kaggle['cmt'] = data_kaggle['text'].map(lambda x: clean_text(x))
df['cmt'] = df['text'].map(lambda x: clean_text(x))

#tokens_ongo=[nltk.word_tokenize(words) for words in data_ongo['cmt']]
#tokens_reddit=[nltk.word_tokenize(words) for words in data_reddit['cmt']]
#tokens_tweet=[nltk.word_tokenize(words) for words in data_tweet['cmt']]
#tokens_kaggle=[nltk.word_tokenize(words) for words in data_kaggle['cmt']]
tokens=[nltk.word_tokenize(words) for words in df['cmt']]

print(tokens)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data_ongo['cmt'] = data_ongo['text'].map(lambda x: clean_text(x))
data_reddit['cmt'] = data_reddit['text'].map(lambda x: clean_text(x))
data_tweet['cmt'] = data_tweet['text'].map(lambda x: clean_text(x))
data_youtube['cmt'] = data_youtube['text'].map(lambda x: clean_text(x))

# %%
data_kaggle['cmt'] = data_kaggle['text'].map(lambda x: clean_text(x))

# %%
tokens_ongo=[nltk.word_tokenize(words) for words in data_ongo['cmt']]
tokens_reddit=[nltk.word_tokenize(words) for words in data_reddit['cmt']]
tokens_tweet=[nltk.word_tokenize(words) for words in data_tweet['cmt']]
tokens_youtube=[nltk.word_tokenize(words) for words in data_youtube['cmt']]

# %%
tokens_kaggle=[nltk.word_tokenize(words) for words in data_kaggle['cmt']]

# %%
print(tokens_ongo[:3])
# Out:
# [['Hello'], ['Got', 'ta', 'get', 'those', 'zzzs'], ['go']]

# %% [markdown]
# **Word2Vec & PCA:**

# %%
#model_ongo = Word2Vec(tokens_ongo,size=70,sg=1,min_count=3)
#model_reddit = Word2Vec(tokens_reddit,size=70,sg=1,min_count=3)
#model_tweet = Word2Vec(tokens_tweet,size=70,sg=1,min_count=3)
#model_kaggle = Word2Vec(tokens_kaggle,size=70,sg=1,min_count=3)
model_df = Word2Vec(tokens,size=70,sg=1,min_count=3)

# %%
model_df.wv.vocab
# Out:
# {'Hello': <gensim.models.keyedvectors.Vocab at 0x7f1a9067f898>,
#  'Got': <gensim.models.keyedvectors.Vocab at 0x7f1a9067f908>,
#  'ta': <gensim.models.keyedvectors.Vocab at 0x7f1a133b09e8>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0a90>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0ac8>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0b00>,
#  'Hey': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0b38>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0b70>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0ba8>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0be0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0c18>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0c50>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0c88>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0cc0>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0cf8>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0d30>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0d68>,
#  'alive': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0da0>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0dd8>,
#  'photos': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0e10>,
#  'Good': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0e48>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0e80>,
#  'Hahaha': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0eb8>,
#  'finding': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0ef0>,
#  'bugs': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0f28>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0f60>,
#  'progress': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0f98>,
#  'That': <gensim.models.keyedvectors.Vocab at 0x7f1a133b0fd0>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4048>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4080>,
#  'scenic': <gensim.models.keyedvectors.Vocab at 0x7f1a133d40b8>,
#  'workout': <gensim.models.keyedvectors.Vocab at 0x7f1a133d40f0>,
#  'spot': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4128>,
#  'lol': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4160>,
#  'looks': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4198>,
#  'fun': <gensim.models.keyedvectors.Vocab at 0x7f1a133d41d0>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4208>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4240>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4278>,
#  'Whoa': <gensim.models.keyedvectors.Vocab at 0x7f1a133d42b0>,
#  'awesome': <gensim.models.keyedvectors.Vocab at 0x7f1a133d42e8>,
#  'guys': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4320>,
#  'Yeah': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4358>,
#  'I': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4390>,
#  'decided': <gensim.models.keyedvectors.Vocab at 0x7f1a133d43c8>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4400>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4438>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4470>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7f1a133d44a8>,
#  'strength': <gensim.models.keyedvectors.Vocab at 0x7f1a133d44e0>,
#  'training': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4518>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4550>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4588>,
#  'Oooh': <gensim.models.keyedvectors.Vocab at 0x7f1a133d45c0>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7f1a133d45f8>,
#  'Looks': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4630>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4668>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7f1a133d46a0>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x7f1a133d46d8>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4710>,
#  'bug': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4748>,
#  'Nice': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4780>,
#  'Keep': <gensim.models.keyedvectors.Vocab at 0x7f1a133d47b8>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7f1a133d47f0>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4828>,
#  'Wow': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4860>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4898>,
#  'Almost': <gensim.models.keyedvectors.Vocab at 0x7f1a133d48d0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4908>,
#  'gainz': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4940>,
#  'adding': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4978>,
#  'comment': <gensim.models.keyedvectors.Vocab at 0x7f1a133d49b0>,
#  'usually': <gensim.models.keyedvectors.Vocab at 0x7f1a133d49e8>,
#  'dread': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4a20>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4a58>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4a90>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4ac8>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4b00>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4b38>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4b70>,
#  're': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4ba8>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4be0>,
#  'doing': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4c18>,
#  'seconds': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4c50>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4c88>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4cc0>,
#  'sessions': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4cf8>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4d30>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4d68>,
#  'program': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4da0>,
#  'She': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4dd8>,
#  'Dang': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4e10>,
#  'Woot': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4e48>,
#  'Daft': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4e80>,
#  'Punk': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4eb8>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4ef0>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4f28>,
#  'Hi': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4f60>,
#  'Christine': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4f98>,
#  'welcome': <gensim.models.keyedvectors.Vocab at 0x7f1a133d4fd0>,
#  'Ongo': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6048>,
#  'Welcome': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6080>,
#  'Yu': <gensim.models.keyedvectors.Vocab at 0x7f1a133d60b8>,
#  'kai': <gensim.models.keyedvectors.Vocab at 0x7f1a133d60f0>,
#  'Abhi': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6128>,
#  'Great': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6160>,
#  'feedback': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6198>,
#  'treadmill': <gensim.models.keyedvectors.Vocab at 0x7f1a133d61d0>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6208>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6240>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6278>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7f1a133d62b0>,
#  'sup': <gensim.models.keyedvectors.Vocab at 0x7f1a133d62e8>,
#  'oh': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6320>,
#  'didnot': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6358>,
#  'realize': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6390>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7f1a133d63c8>,
#  'user': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6400>,
#  'posted': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6438>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6470>,
#  'purdy': <gensim.models.keyedvectors.Vocab at 0x7f1a133d64a8>,
#  'NSFW': <gensim.models.keyedvectors.Vocab at 0x7f1a133d64e0>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6518>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6550>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6588>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x7f1a133d65c0>,
#  'taunt': <gensim.models.keyedvectors.Vocab at 0x7f1a133d65f8>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6630>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6668>,
#  'bitmoji': <gensim.models.keyedvectors.Vocab at 0x7f1a133d66a0>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x7f1a133d66d8>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6710>,
#  'wasnot': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6748>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6780>,
#  'option': <gensim.models.keyedvectors.Vocab at 0x7f1a133d67b8>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x7f1a133d67f0>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6828>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6860>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6898>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7f1a133d68d0>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6908>,
#  'gym': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6940>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6978>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f1a133d69b0>,
#  'lift': <gensim.models.keyedvectors.Vocab at 0x7f1a133d69e8>,
#  'weights': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6a20>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6a58>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6a90>,
#  'apron': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6ac8>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6b00>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6b38>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6b70>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6ba8>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6be0>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6c18>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6c50>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6c88>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6cc0>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6cf8>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6d30>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6d68>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6da0>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6dd8>,
#  'liked': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6e10>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6e48>,
#  'yeah': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6e80>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6eb8>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6ef0>,
#  'killer': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6f28>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6f60>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6f98>,
#  'headphones': <gensim.models.keyedvectors.Vocab at 0x7f1a133d6fd0>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9048>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9080>,
#  'runs': <gensim.models.keyedvectors.Vocab at 0x7f1a133d90b8>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7f1a133d90f0>,
#  'Fat': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9128>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9160>,
#  'wonderful': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9198>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f1a133d91d0>,
#  'sta': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9208>,
#  'Like': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9240>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9278>,
#  'athletic': <gensim.models.keyedvectors.Vocab at 0x7f1a133d92b0>,
#  'Work': <gensim.models.keyedvectors.Vocab at 0x7f1a133d92e8>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9320>,
#  'Where': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9358>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9390>,
#  'Did': <gensim.models.keyedvectors.Vocab at 0x7f1a133d93c8>,
#  'catch': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9400>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9438>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9470>,
#  'overlay': <gensim.models.keyedvectors.Vocab at 0x7f1a133d94a8>,
#  'temperature': <gensim.models.keyedvectors.Vocab at 0x7f1a133d94e0>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9518>,
#  'filter': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9550>,
#  'gon': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9588>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x7f1a133d95c0>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7f1a133d95f8>,
#  'interval': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9630>,
#  'text': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9668>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7f1a133d96a0>,
#  'accurately': <gensim.models.keyedvectors.Vocab at 0x7f1a133d96d8>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9710>,
#  'Sprint': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9748>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9780>,
#  'competitor': <gensim.models.keyedvectors.Vocab at 0x7f1a133d97b8>,
#  'app': <gensim.models.keyedvectors.Vocab at 0x7f1a133d97f0>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9828>,
#  'photo': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9860>,
#  'Oops': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9898>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7f1a133d98d0>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9908>,
#  'haha': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9940>,
#  'Guess': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9978>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7f1a133d99b0>,
#  'ticket': <gensim.models.keyedvectors.Vocab at 0x7f1a133d99e8>,
#  'obviously': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9a20>,
#  'integration': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9a58>,
#  'bruh': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9a90>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9ac8>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9b00>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9b38>,
#  'We': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9b70>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9ba8>,
#  'automatically': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9be0>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9c18>,
#  'signed': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9c50>,
#  'classpass': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9c88>,
#  'Alice': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9cc0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9cf8>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9d30>,
#  'weekly': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9d68>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9da0>,
#  'yup': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9dd8>,
#  'plan': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9e10>,
#  'Yo': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9e48>,
#  'buddy': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9e80>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9eb8>,
#  'Wan': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9ef0>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9f28>,
#  'Or': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9f60>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9f98>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x7f1a133d9fd0>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c048>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c080>,
#  'Small': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c0b8>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c0f0>,
#  'And': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c128>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c160>,
#  'rough': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c198>,
#  'eventually': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c1d0>,
#  'modify': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c208>,
#  'detect': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c240>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c278>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c2b0>,
#  'difficulty': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c2e8>,
#  'dynamically': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c320>,
#  'Nate': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c358>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c390>,
#  'shows': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c3c8>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c400>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c438>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c470>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c4a8>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c4e0>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c518>,
#  'gurl': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c550>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c588>,
#  'scroll': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c5c0>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c5f8>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c630>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c668>,
#  'miles': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c6a0>,
#  'keeping': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c6d8>,
#  'slow': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c710>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c748>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c780>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c7b8>,
#  'update': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c7f0>,
#  'intervals': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c828>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c860>,
#  'chill': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c898>,
#  'donot': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c8d0>,
#  'ton': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c908>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c940>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c978>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c9b0>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7f1a1335c9e8>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x7f1a1335ca20>,
#  'weird': <gensim.models.keyedvectors.Vocab at 0x7f1a1335ca58>,
#  'sprinting': <gensim.models.keyedvectors.Vocab at 0x7f1a1335ca90>,
#  'Damn': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cac8>,
#  'crushing': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cb00>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cb38>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cb70>,
#  'sweat': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cba8>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cbe0>,
#  'So': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cc18>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cc50>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cc88>,
#  'double': <gensim.models.keyedvectors.Vocab at 0x7f1a1335ccc0>,
#  'chicken': <gensim.models.keyedvectors.Vocab at 0x7f1a1335ccf8>,
#  'chopped': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cd30>,
#  'salad': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cd68>,
#  'Subway': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cda0>,
#  'paicular': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cdd8>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7f1a1335ce10>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f1a1335ce48>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7f1a1335ce80>,
#  'improving': <gensim.models.keyedvectors.Vocab at 0x7f1a1335ceb8>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cef0>,
#  'Take': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cf28>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cf60>,
#  'pace': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cf98>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7f1a1335cfd0>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7f1a13360048>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x7f1a13360080>,
#  'car': <gensim.models.keyedvectors.Vocab at 0x7f1a133600b8>,
#  'visualized': <gensim.models.keyedvectors.Vocab at 0x7f1a133600f0>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x7f1a13360128>,
#  'walking': <gensim.models.keyedvectors.Vocab at 0x7f1a13360160>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7f1a13360198>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7f1a133601d0>,
#  'thoughtful': <gensim.models.keyedvectors.Vocab at 0x7f1a13360208>,
#  'remind': <gensim.models.keyedvectors.Vocab at 0x7f1a13360240>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x7f1a13360278>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7f1a133602b0>,
#  'Beast': <gensim.models.keyedvectors.Vocab at 0x7f1a133602e8>,
#  'Also': <gensim.models.keyedvectors.Vocab at 0x7f1a13360320>,
#  'helpful': <gensim.models.keyedvectors.Vocab at 0x7f1a13360358>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f1a13360390>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7f1a133603c8>,
#  'grams': <gensim.models.keyedvectors.Vocab at 0x7f1a13360400>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7f1a13360438>,
#  'wise': <gensim.models.keyedvectors.Vocab at 0x7f1a13360470>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x7f1a133604a8>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x7f1a133604e0>,
#  'strategy': <gensim.models.keyedvectors.Vocab at 0x7f1a13360518>,
#  'Are': <gensim.models.keyedvectors.Vocab at 0x7f1a13360550>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f1a13360588>,
#  'teeth': <gensim.models.keyedvectors.Vocab at 0x7f1a133605c0>,
#  'Haha': <gensim.models.keyedvectors.Vocab at 0x7f1a133605f8>,
#  'burn': <gensim.models.keyedvectors.Vocab at 0x7f1a13360630>,
#  'Said': <gensim.models.keyedvectors.Vocab at 0x7f1a13360668>,
#  'nobody': <gensim.models.keyedvectors.Vocab at 0x7f1a133606a0>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f1a133606d8>,
#  'How': <gensim.models.keyedvectors.Vocab at 0x7f1a13360710>,
#  'recognize': <gensim.models.keyedvectors.Vocab at 0x7f1a13360748>,
#  'Cool': <gensim.models.keyedvectors.Vocab at 0x7f1a13360780>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x7f1a133607b8>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7f1a133607f0>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f1a13360828>,
#  'dawgs': <gensim.models.keyedvectors.Vocab at 0x7f1a13360860>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x7f1a13360898>,
#  'wedded': <gensim.models.keyedvectors.Vocab at 0x7f1a133608d0>,
#  'You': <gensim.models.keyedvectors.Vocab at 0x7f1a13360908>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7f1a13360940>,
#  'Here': <gensim.models.keyedvectors.Vocab at 0x7f1a13360978>,
#  'Commenting': <gensim.models.keyedvectors.Vocab at 0x7f1a133609b0>,
#  'emoji': <gensim.models.keyedvectors.Vocab at 0x7f1a133609e8>,
#  'posts': <gensim.models.keyedvectors.Vocab at 0x7f1a13360a20>,
#  'submit': <gensim.models.keyedvectors.Vocab at 0x7f1a13360a58>,
#  'repo': <gensim.models.keyedvectors.Vocab at 0x7f1a13360a90>,
#  'dream': <gensim.models.keyedvectors.Vocab at 0x7f1a13360ac8>,
#  'jogging': <gensim.models.keyedvectors.Vocab at 0x7f1a13360b00>,
#  'Trying': <gensim.models.keyedvectors.Vocab at 0x7f1a13360b38>,
#  'hashtag': <gensim.models.keyedvectors.Vocab at 0x7f1a13360b70>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7f1a13360ba8>,
#  'considers': <gensim.models.keyedvectors.Vocab at 0x7f1a13360be0>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x7f1a13360c18>,
#  'lesson': <gensim.models.keyedvectors.Vocab at 0x7f1a13360c50>,
#  'lying': <gensim.models.keyedvectors.Vocab at 0x7f1a13360c88>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x7f1a13360cc0>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x7f1a13360cf8>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x7f1a13360d30>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x7f1a13360d68>,
#  'suppos': <gensim.models.keyedvectors.Vocab at 0x7f1a13360da0>,
#  'Om': <gensim.models.keyedvectors.Vocab at 0x7f1a13360dd8>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x7f1a13360e10>,
#  'peace': <gensim.models.keyedvectors.Vocab at 0x7f1a13360e48>,
#  'quiet': <gensim.models.keyedvectors.Vocab at 0x7f1a13360e80>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f1a13360eb8>,
#  'woot': <gensim.models.keyedvectors.Vocab at 0x7f1a13360ef0>,
#  'definitely': <gensim.models.keyedvectors.Vocab at 0x7f1a13360f28>,
#  'inspired': <gensim.models.keyedvectors.Vocab at 0x7f1a13360f60>,
#  'motivated': <gensim.models.keyedvectors.Vocab at 0x7f1a13360f98>,
#  'push': <gensim.models.keyedvectors.Vocab at 0x7f1a13360fd0>,
#  'harder': <gensim.models.keyedvectors.Vocab at 0x7f1a13363048>,
#  'knowing': <gensim.models.keyedvectors.Vocab at 0x7f1a13363080>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x7f1a133630b8>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x7f1a133630f0>,
#  'Awesome': <gensim.models.keyedvectors.Vocab at 0x7f1a13363128>,
#  'Who': <gensim.models.keyedvectors.Vocab at 0x7f1a13363160>,
#  'teaching': <gensim.models.keyedvectors.Vocab at 0x7f1a13363198>,
#  'Stay': <gensim.models.keyedvectors.Vocab at 0x7f1a133631d0>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x7f1a13363208>,
#  'Crushing': <gensim.models.keyedvectors.Vocab at 0x7f1a13363240>,
#  'recipe': <gensim.models.keyedvectors.Vocab at 0x7f1a13363278>,
#  'delicious': <gensim.models.keyedvectors.Vocab at 0x7f1a133632b0>,
#  'healthy': <gensim.models.keyedvectors.Vocab at 0x7f1a133632e8>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f1a13363320>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x7f1a13363358>,
#  'beating': <gensim.models.keyedvectors.Vocab at 0x7f1a13363390>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x7f1a133633c8>,
#  'intense': <gensim.models.keyedvectors.Vocab at 0x7f1a13363400>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x7f1a13363438>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x7f1a13363470>,
#  'Lemonade': <gensim.models.keyedvectors.Vocab at 0x7f1a133634a8>,
#  'SF': <gensim.models.keyedvectors.Vocab at 0x7f1a133634e0>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f1a13363518>,
#  'james': <gensim.models.keyedvectors.Vocab at 0x7f1a13363550>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x7f1a13363588>,
#  't': <gensim.models.keyedvectors.Vocab at 0x7f1a133635c0>,
#  'BBQ': <gensim.models.keyedvectors.Vocab at 0x7f1a133635f8>,
#  'beef': <gensim.models.keyedvectors.Vocab at 0x7f1a13363630>,
#  'brisket': <gensim.models.keyedvectors.Vocab at 0x7f1a13363668>,
#  'mashed': <gensim.models.keyedvectors.Vocab at 0x7f1a133636a0>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x7f1a133636d8>,
#  'potatoes': <gensim.models.keyedvectors.Vocab at 0x7f1a13363710>,
#  'veggies': <gensim.models.keyedvectors.Vocab at 0x7f1a13363748>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7f1a13363780>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7f1a133637b8>,
#  'Nvm': <gensim.models.keyedvectors.Vocab at 0x7f1a133637f0>,
#  'apparently': <gensim.models.keyedvectors.Vocab at 0x7f1a13363828>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7f1a13363860>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x7f1a13363898>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x7f1a133638d0>,
#  'carbs': <gensim.models.keyedvectors.Vocab at 0x7f1a13363908>,
#  'Please': <gensim.models.keyedvectors.Vocab at 0x7f1a13363940>,
#  'pardon': <gensim.models.keyedvectors.Vocab at 0x7f1a13363978>,
#  'dust': <gensim.models.keyedvectors.Vocab at 0x7f1a133639b0>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f1a133639e8>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f1a13363a20>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x7f1a13363a58>,
#  'yummy': <gensim.models.keyedvectors.Vocab at 0x7f1a13363a90>,
#  'Just': <gensim.models.keyedvectors.Vocab at 0x7f1a13363ac8>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x7f1a13363b00>,
#  'wehave': <gensim.models.keyedvectors.Vocab at 0x7f1a13363b38>,
#  'temporarily': <gensim.models.keyedvectors.Vocab at 0x7f1a13363b70>,
#  'disabled': <gensim.models.keyedvectors.Vocab at 0x7f1a13363ba8>,
#  'notifications': <gensim.models.keyedvectors.Vocab at 0x7f1a13363be0>,
#  'wonot': <gensim.models.keyedvectors.Vocab at 0x7f1a13363c18>,
#  'supervision': <gensim.models.keyedvectors.Vocab at 0x7f1a13363c50>,
#  'Coach': <gensim.models.keyedvectors.Vocab at 0x7f1a13363c88>,
#  'Nora': <gensim.models.keyedvectors.Vocab at 0x7f1a13363cc0>,
#  'burpees': <gensim.models.keyedvectors.Vocab at 0x7f1a13363cf8>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7f1a13363d30>,
#  'Bonus': <gensim.models.keyedvectors.Vocab at 0x7f1a13363d68>,
#  'didn': <gensim.models.keyedvectors.Vocab at 0x7f1a13363da0>,
#  'Yup': <gensim.models.keyedvectors.Vocab at 0x7f1a13363dd8>,
#  'swag': <gensim.models.keyedvectors.Vocab at 0x7f1a13363e10>,
#  'sell': <gensim.models.keyedvectors.Vocab at 0x7f1a13363e48>,
#  'gear': <gensim.models.keyedvectors.Vocab at 0x7f1a13363e80>,
#  'directly': <gensim.models.keyedvectors.Vocab at 0x7f1a13363eb8>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f1a13363ef0>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x7f1a13363f28>,
#  'tracking': <gensim.models.keyedvectors.Vocab at 0x7f1a13363f60>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7f1a13363f98>,
#  'overhaul': <gensim.models.keyedvectors.Vocab at 0x7f1a13363fd0>,
#  'But': <gensim.models.keyedvectors.Vocab at 0x7f1a13367048>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f1a13367080>,
#  'figure': <gensim.models.keyedvectors.Vocab at 0x7f1a133670b8>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f1a133670f0>,
#  'integrate': <gensim.models.keyedvectors.Vocab at 0x7f1a13367128>,
#  'Strava': <gensim.models.keyedvectors.Vocab at 0x7f1a13367160>,
#  'optimal': <gensim.models.keyedvectors.Vocab at 0x7f1a13367198>,
#  'Thanks': <gensim.models.keyedvectors.Vocab at 0x7f1a133671d0>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x7f1a13367208>,
#  'community': <gensim.models.keyedvectors.Vocab at 0x7f1a13367240>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f1a13367278>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x7f1a133672b0>,
#  'Note': <gensim.models.keyedvectors.Vocab at 0x7f1a133672e8>,
#  'dumb': <gensim.models.keyedvectors.Vocab at 0x7f1a13367320>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7f1a13367358>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x7f1a13367390>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x7f1a133673c8>,
#  'Future': <gensim.models.keyedvectors.Vocab at 0x7f1a13367400>,
#  'iterations': <gensim.models.keyedvectors.Vocab at 0x7f1a13367438>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f1a13367470>,
#  'sma': <gensim.models.keyedvectors.Vocab at 0x7f1a133674a8>,
#  'delivery': <gensim.models.keyedvectors.Vocab at 0x7f1a133674e0>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x7f1a13367518>,
#  'notification': <gensim.models.keyedvectors.Vocab at 0x7f1a13367550>,
#  'overwhelm': <gensim.models.keyedvectors.Vocab at 0x7f1a13367588>,
#  'Disappointed': <gensim.models.keyedvectors.Vocab at 0x7f1a133675c0>,
#  'missed': <gensim.models.keyedvectors.Vocab at 0x7f1a133675f8>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f1a13367630>,
#  'On': <gensim.models.keyedvectors.Vocab at 0x7f1a13367668>,
#  'bright': <gensim.models.keyedvectors.Vocab at 0x7f1a133676a0>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x7f1a133676d8>,
#  'throat': <gensim.models.keyedvectors.Vocab at 0x7f1a13367710>,
#  'sore': <gensim.models.keyedvectors.Vocab at 0x7f1a13367748>,
#  'hopefully': <gensim.models.keyedvectors.Vocab at 0x7f1a13367780>,
#  'tomorrow': <gensim.models.keyedvectors.Vocab at 0x7f1a133677b8>,
#  'Kudos': <gensim.models.keyedvectors.Vocab at 0x7f1a133677f0>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x7f1a13367828>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x7f1a13367860>,
#  'ugly': <gensim.models.keyedvectors.Vocab at 0x7f1a13367898>,
#  'weather': <gensim.models.keyedvectors.Vocab at 0x7f1a133678d0>,
#  'Never': <gensim.models.keyedvectors.Vocab at 0x7f1a13367908>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7f1a13367940>,
#  'Bar': <gensim.models.keyedvectors.Vocab at 0x7f1a13367978>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7f1a133679b0>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7f1a133679e8>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f1a13367a20>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x7f1a13367a58>,
#  'It': <gensim.models.keyedvectors.Vocab at 0x7f1a13367a90>,
#  'recommend': <gensim.models.keyedvectors.Vocab at 0x7f1a13367ac8>,
#  'Maybe': <gensim.models.keyedvectors.Vocab at 0x7f1a13367b00>,
#  'mall': <gensim.models.keyedvectors.Vocab at 0x7f1a13367b38>,
#  'shopping': <gensim.models.keyedvectors.Vocab at 0x7f1a13367b70>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x7f1a13367ba8>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x7f1a13367be0>,
#  'totally': <gensim.models.keyedvectors.Vocab at 0x7f1a13367c18>,
#  'drenched': <gensim.models.keyedvectors.Vocab at 0x7f1a13367c50>,
#  'LA': <gensim.models.keyedvectors.Vocab at 0x7f1a13367c88>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7f1a13367cc0>,
#  'The': <gensim.models.keyedvectors.Vocab at 0x7f1a13367cf8>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x7f1a13367d30>,
#  'lied': <gensim.models.keyedvectors.Vocab at 0x7f1a13367d68>,
#  'sunny': <gensim.models.keyedvectors.Vocab at 0x7f1a13367da0>,
#  'SoCal': <gensim.models.keyedvectors.Vocab at 0x7f1a13367dd8>,
#  'flexibility': <gensim.models.keyedvectors.Vocab at 0x7f1a13367e10>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7f1a13367e48>,
#  'TRE': <gensim.models.keyedvectors.Vocab at 0x7f1a13367e80>,
#  'programs': <gensim.models.keyedvectors.Vocab at 0x7f1a13367eb8>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x7f1a13367ef0>,
#  'Which': <gensim.models.keyedvectors.Vocab at 0x7f1a13367f28>,
#  'session': <gensim.models.keyedvectors.Vocab at 0x7f1a13367f60>,
#  'Cross': <gensim.models.keyedvectors.Vocab at 0x7f1a13367f98>,
#  'Training': <gensim.models.keyedvectors.Vocab at 0x7f1a13367fd0>,
#  'Single': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b048>,
#  'Session': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b080>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b0b8>,
#  'This': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b0f0>,
#  'Paige': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b128>,
#  'Way': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b160>,
#  'Craig': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b198>,
#  'elevation': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b1d0>,
#  'Epic': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b208>,
#  'Beard': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b240>,
#  'My': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b278>,
#  'thighs': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b2b0>,
#  'burning': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b2e8>,
#  'Definitely': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b320>,
#  'leg': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b358>,
#  'Gon': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b390>,
#  'BRP': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b3c8>,
#  'Monday': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b400>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b438>,
#  'wake': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b470>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b4a8>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b4e0>,
#  'nicely': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b518>,
#  'What': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b550>,
#  'hands': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b588>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b5c0>,
#  'yoga': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b5f8>,
#  'basically': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b630>,
#  'helps': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b668>,
#  'preserve': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b6a0>,
#  'wrists': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b6d8>,
#  'alternate': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b710>,
#  'moves': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b748>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b780>,
#  'wrist': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b7b8>,
#  'injuries': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b7f0>,
#  'Doctor': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b828>,
#  'sick': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b860>,
#  'moon': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b898>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b8d0>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b908>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b940>,
#  'Lisa': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b978>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b9b0>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x7f1a1336b9e8>,
#  'spo': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ba20>,
#  'Paul': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ba58>,
#  'treacherous': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ba90>,
#  'Love': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bac8>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bb00>,
#  'climbing': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bb38>,
#  'runners': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bb70>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bba8>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bbe0>,
#  'climber': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bc18>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bc50>,
#  'muscles': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bc88>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bcc0>,
#  'translate': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bcf8>,
#  'somehow': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bd30>,
#  'Miles': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bd68>,
#  'veical': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bda0>,
#  'horizontal': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bdd8>,
#  'yikes': <gensim.models.keyedvectors.Vocab at 0x7f1a1336be10>,
#  'careful': <gensim.models.keyedvectors.Vocab at 0x7f1a1336be48>,
#  'Ihave': <gensim.models.keyedvectors.Vocab at 0x7f1a1336be80>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7f1a1336beb8>,
#  'met': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bef0>,
#  'climb': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bf28>,
#  'Eastern': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bf60>,
#  'Sierra': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bf98>,
#  'crossover': <gensim.models.keyedvectors.Vocab at 0x7f1a1336bfd0>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e048>,
#  'trail': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e080>,
#  'climbers': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e0b8>,
#  'bc': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e0f0>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e128>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e160>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e198>,
#  'sets': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e1d0>,
#  'skills': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e208>,
#  'Correct': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e240>,
#  'For': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e278>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e2b0>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e2e8>,
#  'Garmin': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e320>,
#  'functionality': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e358>,
#  'False': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e390>,
#  'Creek': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e3c8>,
#  'Vancouver': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e400>,
#  'BC': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e438>,
#  'beach': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e470>,
#  'location': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e4a8>,
#  'loved': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e4e0>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e518>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e550>,
#  'imagine': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e588>,
#  'finishing': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e5c0>,
#  'marathon': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e5f8>,
#  'torn': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e630>,
#  'tendon': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e668>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e6a0>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e6d8>,
#  'Best': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e710>,
#  'luck': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e748>,
#  'healing': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e780>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e7b8>,
#  'Boston': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e7f0>,
#  'Heh': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e828>,
#  'rock': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e860>,
#  'mark': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e898>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e8d0>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e908>,
#  'tear': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e940>,
#  'squatting': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e978>,
#  'lunges': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e9b0>,
#  'deadlifts': <gensim.models.keyedvectors.Vocab at 0x7f1a1336e9e8>,
#  'lots': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ea20>,
#  'hamstring': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ea58>,
#  'glute': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ea90>,
#  'bridges': <gensim.models.keyedvectors.Vocab at 0x7f1a1336eac8>,
#  'fit': <gensim.models.keyedvectors.Vocab at 0x7f1a1336eb00>,
#  'dialed': <gensim.models.keyedvectors.Vocab at 0x7f1a1336eb38>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x7f1a1336eb70>,
#  'bothers': <gensim.models.keyedvectors.Vocab at 0x7f1a1336eba8>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ebe0>,
#  'speed': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ec18>,
#  'lights': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ec50>,
#  'MRI': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ec88>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ecc0>,
#  'Feb': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ecf8>,
#  'followed': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ed30>,
#  'PRP': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ed68>,
#  'injection': <gensim.models.keyedvectors.Vocab at 0x7f1a1336eda0>,
#  'wasn': <gensim.models.keyedvectors.Vocab at 0x7f1a1336edd8>,
#  'allowed': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ee10>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ee48>,
#  'Tokyo': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ee80>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x7f1a1336eeb8>,
#  'sightseeing': <gensim.models.keyedvectors.Vocab at 0x7f1a1336eef0>,
#  'restaing': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ef28>,
#  'sho': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ef60>,
#  'km': <gensim.models.keyedvectors.Vocab at 0x7f1a1336ef98>,
#  'slower': <gensim.models.keyedvectors.Vocab at 0x7f1a1336efd0>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7f1a13372048>,
#  'intended': <gensim.models.keyedvectors.Vocab at 0x7f1a13372080>,
#  'planned': <gensim.models.keyedvectors.Vocab at 0x7f1a133720b8>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x7f1a133720f0>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7f1a13372128>,
#  'goal': <gensim.models.keyedvectors.Vocab at 0x7f1a13372160>,
#  'Speed': <gensim.models.keyedvectors.Vocab at 0x7f1a13372198>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x7f1a133721d0>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7f1a13372208>,
#  'min': <gensim.models.keyedvectors.Vocab at 0x7f1a13372240>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f1a13372278>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7f1a133722b0>,
#  'Glad': <gensim.models.keyedvectors.Vocab at 0x7f1a133722e8>,
#  'mornings': <gensim.models.keyedvectors.Vocab at 0x7f1a13372320>,
#  'woohoo': <gensim.models.keyedvectors.Vocab at 0x7f1a13372358>,
#  'staing': <gensim.models.keyedvectors.Vocab at 0x7f1a13372390>,
#  'hardest': <gensim.models.keyedvectors.Vocab at 0x7f1a133723c8>,
#  'pas': <gensim.models.keyedvectors.Vocab at 0x7f1a13372400>,
#  'hike': <gensim.models.keyedvectors.Vocab at 0x7f1a13372438>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f1a13372470>,
#  'weekend': <gensim.models.keyedvectors.Vocab at 0x7f1a133724a8>,
#  'summit': <gensim.models.keyedvectors.Vocab at 0x7f1a133724e0>,
#  'Shot': <gensim.models.keyedvectors.Vocab at 0x7f1a13372518>,
#  'iPhone': <gensim.models.keyedvectors.Vocab at 0x7f1a13372550>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x7f1a13372588>,
#  'Happy': <gensim.models.keyedvectors.Vocab at 0x7f1a133725c0>,
#  'Amber': <gensim.models.keyedvectors.Vocab at 0x7f1a133725f8>,
#  'Does': <gensim.models.keyedvectors.Vocab at 0x7f1a13372630>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x7f1a13372668>,
#  'leash': <gensim.models.keyedvectors.Vocab at 0x7f1a133726a0>,
#  'train': <gensim.models.keyedvectors.Vocab at 0x7f1a133726d8>,
#  'required': <gensim.models.keyedvectors.Vocab at 0x7f1a13372710>,
#  'preserves': <gensim.models.keyedvectors.Vocab at 0x7f1a13372748>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7f1a13372780>,
#  'learning': <gensim.models.keyedvectors.Vocab at 0x7f1a133727b8>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7f1a133727f0>,
#  'package': <gensim.models.keyedvectors.Vocab at 0x7f1a13372828>,
#  'glad': <gensim.models.keyedvectors.Vocab at 0x7f1a13372860>,
#  'enjoying': <gensim.models.keyedvectors.Vocab at 0x7f1a13372898>,
#  'Daniel': <gensim.models.keyedvectors.Vocab at 0x7f1a133728d0>,
#  'challenge': <gensim.models.keyedvectors.Vocab at 0x7f1a13372908>,
#  'tests': <gensim.models.keyedvectors.Vocab at 0x7f1a13372940>,
#  'referring': <gensim.models.keyedvectors.Vocab at 0x7f1a13372978>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7f1a133729b0>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x7f1a133729e8>,
#  'tapping': <gensim.models.keyedvectors.Vocab at 0x7f1a13372a20>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f1a13372a58>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x7f1a13372a90>,
#  'icon': <gensim.models.keyedvectors.Vocab at 0x7f1a13372ac8>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7f1a13372b00>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f1a13372b38>,
#  'screen': <gensim.models.keyedvectors.Vocab at 0x7f1a13372b70>,
#  'Shirley': <gensim.models.keyedvectors.Vocab at 0x7f1a13372ba8>,
#  'Wehave': <gensim.models.keyedvectors.Vocab at 0x7f1a13372be0>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x7f1a13372c18>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7f1a13372c50>,
#  'improvements': <gensim.models.keyedvectors.Vocab at 0x7f1a13372c88>,
#  'GPS': <gensim.models.keyedvectors.Vocab at 0x7f1a13372cc0>,
#  'tracker': <gensim.models.keyedvectors.Vocab at 0x7f1a13372cf8>,
#  'thanks': <gensim.models.keyedvectors.Vocab at 0x7f1a13372d30>,
#  'sent': <gensim.models.keyedvectors.Vocab at 0x7f1a13372d68>,
#  'sharing': <gensim.models.keyedvectors.Vocab at 0x7f1a13372da0>,
#  'Geoffrey': <gensim.models.keyedvectors.Vocab at 0x7f1a13372dd8>,
#  'beta': <gensim.models.keyedvectors.Vocab at 0x7f1a13372e10>,
#  'continue': <gensim.models.keyedvectors.Vocab at 0x7f1a13372e48>,
#  'There': <gensim.models.keyedvectors.Vocab at 0x7f1a13372e80>,
#  'options': <gensim.models.keyedvectors.Vocab at 0x7f1a13372eb8>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x7f1a13372ef0>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7f1a13372f28>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x7f1a13372f60>,
#  'tuned': <gensim.models.keyedvectors.Vocab at 0x7f1a13372f98>,
# ...
#  'who': <gensim.models.keyedvectors.Vocab at 0x7f1a13375198>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x7f1a133751d0>,
#  'willing': <gensim.models.keyedvectors.Vocab at 0x7f1a13375208>,
#  'jump': <gensim.models.keyedvectors.Vocab at 0x7f1a13375240>,
#  'Outdoors': <gensim.models.keyedvectors.Vocab at 0x7f1a13375278>,
#  'Susan': <gensim.models.keyedvectors.Vocab at 0x7f1a133752b0>,
#  'Any': <gensim.models.keyedvectors.Vocab at 0x7f1a133752e8>,
#  'suggestions': <gensim.models.keyedvectors.Vocab at 0x7f1a13375320>,
#  'captain': <gensim.models.keyedvectors.Vocab at 0x7f1a13375358>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x7f1a13375390>,
#  'Ask': <gensim.models.keyedvectors.Vocab at 0x7f1a133753c8>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x7f1a13375400>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x7f1a13375438>,
#  'hat': <gensim.models.keyedvectors.Vocab at 0x7f1a13375470>,
#  'collection': <gensim.models.keyedvectors.Vocab at 0x7f1a133754a8>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7f1a133754e0>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x7f1a13375518>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x7f1a13375550>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x7f1a13375588>,
#  'apps': <gensim.models.keyedvectors.Vocab at 0x7f1a133755c0>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x7f1a133755f8>,
#  'problems': <gensim.models.keyedvectors.Vocab at 0x7f1a13375630>,
#  'streaming': <gensim.models.keyedvectors.Vocab at 0x7f1a13375668>,
#  'trails': <gensim.models.keyedvectors.Vocab at 0x7f1a133756a0>,
#  'downloaded': <gensim.models.keyedvectors.Vocab at 0x7f1a133756d8>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x7f1a13375710>,
#  'perfectly': <gensim.models.keyedvectors.Vocab at 0x7f1a13375748>,
#  'Jorge': <gensim.models.keyedvectors.Vocab at 0x7f1a13375780>,
#  'enabling': <gensim.models.keyedvectors.Vocab at 0x7f1a133757b8>,
#  'terms': <gensim.models.keyedvectors.Vocab at 0x7f1a133757f0>,
#  'deleting': <gensim.models.keyedvectors.Vocab at 0x7f1a13375828>,
#  'activities': <gensim.models.keyedvectors.Vocab at 0x7f1a13375860>,
#  'heating': <gensim.models.keyedvectors.Vocab at 0x7f1a13375898>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x7f1a133758d0>,
#  'specifically': <gensim.models.keyedvectors.Vocab at 0x7f1a13375908>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x7f1a13375940>,
#  'kinks': <gensim.models.keyedvectors.Vocab at 0x7f1a13375978>,
#  'impo': <gensim.models.keyedvectors.Vocab at 0x7f1a133759b0>,
#  'Rick': <gensim.models.keyedvectors.Vocab at 0x7f1a133759e8>,
#  'Truthfully': <gensim.models.keyedvectors.Vocab at 0x7f1a13375a20>,
#  'trackers': <gensim.models.keyedvectors.Vocab at 0x7f1a13375a58>,
#  'Whoo': <gensim.models.keyedvectors.Vocab at 0x7f1a13375a90>,
#  'hoo': <gensim.models.keyedvectors.Vocab at 0x7f1a13375ac8>,
#  'Elizabeth': <gensim.models.keyedvectors.Vocab at 0x7f1a13375b00>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x7f1a13375b38>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x7f1a13375b70>,
#  'audio': <gensim.models.keyedvectors.Vocab at 0x7f1a13375ba8>,
#  'workouts': <gensim.models.keyedvectors.Vocab at 0x7f1a13375be0>,
#  'Canot': <gensim.models.keyedvectors.Vocab at 0x7f1a13375c18>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x7f1a13375c50>,
#  'Kathy': <gensim.models.keyedvectors.Vocab at 0x7f1a13375c88>,
#  'updating': <gensim.models.keyedvectors.Vocab at 0x7f1a13375cc0>,
#  'changes': <gensim.models.keyedvectors.Vocab at 0x7f1a13375cf8>,
#  'Let': <gensim.models.keyedvectors.Vocab at 0x7f1a13375d30>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7f1a13375d68>,
#  'ditto': <gensim.models.keyedvectors.Vocab at 0x7f1a13375da0>,
#  'skipped': <gensim.models.keyedvectors.Vocab at 0x7f1a13375dd8>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x7f1a13375e10>,
#  'decade': <gensim.models.keyedvectors.Vocab at 0x7f1a13375e48>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7f1a13375e80>,
#  'Seems': <gensim.models.keyedvectors.Vocab at 0x7f1a13375eb8>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7f1a13375ef0>,
#  'intro': <gensim.models.keyedvectors.Vocab at 0x7f1a13375f28>,
#  'highlights': <gensim.models.keyedvectors.Vocab at 0x7f1a13375f60>,
#  'beginner': <gensim.models.keyedvectors.Vocab at 0x7f1a13375f98>,
#  'mistakes': <gensim.models.keyedvectors.Vocab at 0x7f1a13375fd0>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x7f1a13379048>,
#  'staed': <gensim.models.keyedvectors.Vocab at 0x7f1a13379080>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f1a133790b8>,
#  'spreading': <gensim.models.keyedvectors.Vocab at 0x7f1a133790f0>,
#  'affect': <gensim.models.keyedvectors.Vocab at 0x7f1a13379128>,
#  'Mike': <gensim.models.keyedvectors.Vocab at 0x7f1a13379160>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x7f1a13379198>,
#  'BTW': <gensim.models.keyedvectors.Vocab at 0x7f1a133791d0>,
#  'graphics': <gensim.models.keyedvectors.Vocab at 0x7f1a13379208>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x7f1a13379240>,
#  'setting': <gensim.models.keyedvectors.Vocab at 0x7f1a13379278>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x7f1a133792b0>,
#  'M': <gensim.models.keyedvectors.Vocab at 0x7f1a133792e8>,
#  'Run': <gensim.models.keyedvectors.Vocab at 0x7f1a13379320>,
#  'Yay': <gensim.models.keyedvectors.Vocab at 0x7f1a13379358>,
#  'excited': <gensim.models.keyedvectors.Vocab at 0x7f1a13379390>,
#  'Destiny': <gensim.models.keyedvectors.Vocab at 0x7f1a133793c8>,
#  'Omg': <gensim.models.keyedvectors.Vocab at 0x7f1a13379400>,
#  'Angela': <gensim.models.keyedvectors.Vocab at 0x7f1a13379438>,
#  'Thank': <gensim.models.keyedvectors.Vocab at 0x7f1a13379470>,
#  'journey': <gensim.models.keyedvectors.Vocab at 0x7f1a133794a8>,
#  'Tommy': <gensim.models.keyedvectors.Vocab at 0x7f1a133794e0>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x7f1a13379518>,
#  'joining': <gensim.models.keyedvectors.Vocab at 0x7f1a13379550>,
#  'Lol': <gensim.models.keyedvectors.Vocab at 0x7f1a13379588>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x7f1a133795c0>,
#  'Robe': <gensim.models.keyedvectors.Vocab at 0x7f1a133795f8>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x7f1a13379630>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x7f1a13379668>,
#  'Very': <gensim.models.keyedvectors.Vocab at 0x7f1a133796a0>,
#  'sounds': <gensim.models.keyedvectors.Vocab at 0x7f1a133796d8>,
#  'amazing': <gensim.models.keyedvectors.Vocab at 0x7f1a13379710>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x7f1a13379748>,
#  'Chicago': <gensim.models.keyedvectors.Vocab at 0x7f1a13379780>,
#  'Come': <gensim.models.keyedvectors.Vocab at 0x7f1a133797b8>,
#  'spring': <gensim.models.keyedvectors.Vocab at 0x7f1a133797f0>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7f1a13379828>,
#  'lucky': <gensim.models.keyedvectors.Vocab at 0x7f1a13379860>,
#  'Lovely': <gensim.models.keyedvectors.Vocab at 0x7f1a13379898>,
#  'Yikes': <gensim.models.keyedvectors.Vocab at 0x7f1a133798d0>,
#  'Well': <gensim.models.keyedvectors.Vocab at 0x7f1a13379908>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7f1a13379940>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x7f1a13379978>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x7f1a133799b0>,
#  'Ed': <gensim.models.keyedvectors.Vocab at 0x7f1a133799e8>,
#  'Sorry': <gensim.models.keyedvectors.Vocab at 0x7f1a13379a20>,
#  'trouble': <gensim.models.keyedvectors.Vocab at 0x7f1a13379a58>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x7f1a13379a90>,
#  'updates': <gensim.models.keyedvectors.Vocab at 0x7f1a13379ac8>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7f1a13379b00>,
#  'squash': <gensim.models.keyedvectors.Vocab at 0x7f1a13379b38>,
#  'technical': <gensim.models.keyedvectors.Vocab at 0x7f1a13379b70>,
#  'suppo': <gensim.models.keyedvectors.Vocab at 0x7f1a13379ba8>,
#  'gets': <gensim.models.keyedvectors.Vocab at 0x7f1a13379be0>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x7f1a13379c18>,
#  'engineering': <gensim.models.keyedvectors.Vocab at 0x7f1a13379c50>,
#  'Beautiful': <gensim.models.keyedvectors.Vocab at 0x7f1a13379c88>,
#  'view': <gensim.models.keyedvectors.Vocab at 0x7f1a13379cc0>,
#  'sunglasses': <gensim.models.keyedvectors.Vocab at 0x7f1a13379cf8>,
#  'Nicely': <gensim.models.keyedvectors.Vocab at 0x7f1a13379d30>,
#  'Easy': <gensim.models.keyedvectors.Vocab at 0x7f1a13379d68>,
#  'bike': <gensim.models.keyedvectors.Vocab at 0x7f1a13379da0>,
#  'ride': <gensim.models.keyedvectors.Vocab at 0x7f1a13379dd8>,
#  'path': <gensim.models.keyedvectors.Vocab at 0x7f1a13379e10>,
#  'Our': <gensim.models.keyedvectors.Vocab at 0x7f1a13379e48>,
#  'recovery': <gensim.models.keyedvectors.Vocab at 0x7f1a13379e80>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x7f1a13379eb8>,
#  'woods': <gensim.models.keyedvectors.Vocab at 0x7f1a13379ef0>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x7f1a13379f28>,
#  'street': <gensim.models.keyedvectors.Vocab at 0x7f1a13379f60>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x7f1a13379f98>,
#  'bringing': <gensim.models.keyedvectors.Vocab at 0x7f1a13379fd0>,
#  'wine': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c048>,
#  'tho': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c080>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c0b8>,
#  'Troy': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c0f0>,
#  'k': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c128>,
#  'Those': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c160>,
#  'pulling': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c198>,
#  'drills': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c1d0>,
#  'Completely': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c208>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c240>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c278>,
#  'Pete': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c2b0>,
#  'appreciated': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c2e8>,
#  'Carmen': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c320>,
#  'Sounds': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c358>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c390>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c3c8>,
#  'interpreting': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c400>,
#  'Sydney': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c438>,
#  'conditions': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c470>,
#  'involve': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c4a8>,
#  'bunch': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c4e0>,
#  'clouds': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c518>,
#  'disagree': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c550>,
#  'crisp': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c588>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c5c0>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c5f8>,
#  've': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c630>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c668>,
#  'Autumn': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c6a0>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c6d8>,
#  'cooler': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c710>,
#  'cloudy': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c748>,
#  'Really': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c780>,
#  'smashing': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c7b8>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c7f0>,
#  'figures': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c828>,
#  'Had': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c860>,
#  'meeting': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c898>,
#  'Everyone': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c8d0>,
#  'seeing': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c908>,
#  'Wish': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c940>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c978>,
#  'impoant': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c9b0>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x7f1a1337c9e8>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f1a1337ca20>,
#  'Congrats': <gensim.models.keyedvectors.Vocab at 0x7f1a1337ca58>,
#  'commitment': <gensim.models.keyedvectors.Vocab at 0x7f1a1337ca90>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cac8>,
#  'Hopefully': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cb00>,
#  'reaching': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cb38>,
#  'goals': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cb70>,
#  'Running': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cba8>,
#  'anyone': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cbe0>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cc18>,
#  'runner': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cc50>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cc88>,
#  'experienced': <gensim.models.keyedvectors.Vocab at 0x7f1a1337ccc0>,
#  'ebbs': <gensim.models.keyedvectors.Vocab at 0x7f1a1337ccf8>,
#  'flows': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cd30>,
#  'DC': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cd68>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cda0>,
#  'periods': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cdd8>,
#  'ultimate': <gensim.models.keyedvectors.Vocab at 0x7f1a1337ce10>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7f1a1337ce48>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x7f1a1337ce80>,
#  'intermediate': <gensim.models.keyedvectors.Vocab at 0x7f1a1337ceb8>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cef0>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cf28>,
#  'expe': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cf60>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cf98>,
#  'discomfo': <gensim.models.keyedvectors.Vocab at 0x7f1a1337cfd0>,
#  'fatigue': <gensim.models.keyedvectors.Vocab at 0x7f1a13380048>,
#  'defer': <gensim.models.keyedvectors.Vocab at 0x7f1a13380080>,
#  'myself': <gensim.models.keyedvectors.Vocab at 0x7f1a133800b8>,
#  'suspect': <gensim.models.keyedvectors.Vocab at 0x7f1a133800f0>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7f1a13380128>,
#  'exercises': <gensim.models.keyedvectors.Vocab at 0x7f1a13380160>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7f1a13380198>,
#  'youhave': <gensim.models.keyedvectors.Vocab at 0x7f1a133801d0>,
#  'noticed': <gensim.models.keyedvectors.Vocab at 0x7f1a13380208>,
#  'Bay': <gensim.models.keyedvectors.Vocab at 0x7f1a13380240>,
#  'Breakers': <gensim.models.keyedvectors.Vocab at 0x7f1a13380278>,
#  'San': <gensim.models.keyedvectors.Vocab at 0x7f1a133802b0>,
#  'Francisco': <gensim.models.keyedvectors.Vocab at 0x7f1a133802e8>,
#  'If': <gensim.models.keyedvectors.Vocab at 0x7f1a13380320>,
#  'Sending': <gensim.models.keyedvectors.Vocab at 0x7f1a13380358>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x7f1a13380390>,
#  'vibes': <gensim.models.keyedvectors.Vocab at 0x7f1a133803c8>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7f1a13380400>,
#  'clarify': <gensim.models.keyedvectors.Vocab at 0x7f1a13380438>,
#  'definite': <gensim.models.keyedvectors.Vocab at 0x7f1a13380470>,
#  'weakness': <gensim.models.keyedvectors.Vocab at 0x7f1a133804a8>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7f1a133804e0>,
#  'noticeable': <gensim.models.keyedvectors.Vocab at 0x7f1a13380518>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x7f1a13380550>,
#  'effo': <gensim.models.keyedvectors.Vocab at 0x7f1a13380588>,
#  'maintain': <gensim.models.keyedvectors.Vocab at 0x7f1a133805c0>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x7f1a133805f8>,
#  'calf': <gensim.models.keyedvectors.Vocab at 0x7f1a13380630>,
#  'hip': <gensim.models.keyedvectors.Vocab at 0x7f1a13380668>,
#  'dropping': <gensim.models.keyedvectors.Vocab at 0x7f1a133806a0>,
#  'Yes': <gensim.models.keyedvectors.Vocab at 0x7f1a133806d8>,
#  'event': <gensim.models.keyedvectors.Vocab at 0x7f1a13380710>,
#  'spoken': <gensim.models.keyedvectors.Vocab at 0x7f1a13380748>,
#  'crew': <gensim.models.keyedvectors.Vocab at 0x7f1a13380780>,
#  'plans': <gensim.models.keyedvectors.Vocab at 0x7f1a133807b8>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f1a133807f0>,
#  ...}

# %%
#model_ongo = Word2Vec(tokens_ongo,size=70,sg=1,min_count=3)
#model_reddit = Word2Vec(tokens_reddit,size=70,sg=1,min_count=3)
#model_tweet = Word2Vec(tokens_tweet,size=70,sg=1,min_count=3)
#model_tweet = Word2Vec(tokens_tweet,size=70,sg=1,min_count=3)

# %% [markdown]
# Further, we will store all the word vectors in the data frame with 70 dimensions and use this data frame for PCA.

# %%
def List(list):
  """making a list from all lists and sublists"""
  L = []
  for i in list:
    for j in i:
      L.append(j)
  return L

# %%
words_ongo=List(tokens_ongo)
words_reddit=List(tokens_reddit)
words_tweet=List(tokens_tweet)
words_kaggle=List(tokens_kaggle)
words_youtube=List(tokens_youtube)
words = list(model_df.wv.vocab)

print(words_ongo)
# Out:
# ['Hello', 'Got', 'ta', 'get', 'those', 'zzzs', 'go', 'go', 'ongo', 'go', 'Hey', 'can', 'not', 'wait', 'to', 'release', 'the', 'new', 'version', 'Newsfeed', 'should', 'get', 'come', 'alive', 'with', 'photos', 'Good', 'job', 'Hahaha', 'finding', 'bugs', 'is', 'progress', 'That', 's', 'a', 'scenic', 'workout', 'spot', 'lol', 'That', 'looks', 'fun', 'That', 's', 'a', 'really', 'good', 'idea', 'Whoa', 'That', 's', 'awesome', 'guys', 'Yeah', 'I', 'decided', 'to', 'run', 'and', 'do', 'some', 'strength', 'training', 'for', 'fun', 'day', 'Oooh', 'nice', 'Looks', 'like', 'we', 'found', 'another', 'bug', 'Nice', 'Keep', 'it', 'going', 'Wow', 'nice', 'that', 's', 'awesome', 'Almost', 'there', 'Nice', 'gainz', 'adding', 'a', 'new', 'comment', 'Got', 'ta', 'get', 'those', 'gainz', 'Yeah', 'I', 'usually', 'dread', 'them', 'but', 'it', 's', 'not', 'so', 'bad', 'if', 'you', 're', 'only', 'doing', 'it', 'for', 'seconds', 'I', 'm', 'savoring', 'the', 'last', 'sessions', 'of', 'this', 'program', 'She', 's', 'really', 'good', 'Dang', 'Woot', 'and', 'Daft', 'Punk', 'comes', 'on', 'Hi', 'Christine', 'welcome', 'to', 'Ongo', 'Welcome', 'Yu', 'kai', 'Nice', 'run', 'Abhi', 'Great', 'feedback', 'on', 'the', 'treadmill', 'we', 'll', 'try', 'to', 'improve', 'that', 'experience', 'That', 's', 'awesome', 'W00t', 'sup', 'oh', 'didnot', 'realize', 'this', 'was', 'a', 'user', 'posted', 'picture', 'looks', 'so', 'purdy', 'NSFW', 'yes', 'lol', 'and', 'be', 'able', 'to', 'add', 'taunt', 'another', 'person', 'through', 'bitmoji', 'I', 'did', 'finish', 'but', 'wasnot', 'given', 'the', 'option', 'to', 'post', 'my', 'run', 'i', 'was', 'but', 'then', 'I', 'just', 'went', 'to', 'the', 'gym', 'so', 'I', 'could', 'also', 'lift', 'weights', 'that', 'would', 'be', 'perfect', 'apron', 'style', 'before', 'sessions', 'tell', 'me', 'what', 'things', 'I', 'need', 'and', 'give', 'me', 'the', 'option', 'to', 'order', 'them', 'or', 'make', 'sure', 'I', 'have', 'them', '1', 'manny', 'liked', 'your', 'comment', 'yeah', 'walk', 'and', 'run', 'every', 'seconds', 'was', 'a', 'killer', 'but', 'felt', 'good', 'after', 'what', 'headphones', 'are', 'you', 'using', 'for', 'your', 'runs', 'actually', 'it', 'was', 'really', 'nice', 'Fat', 'Burner', 'Wow', 'that', 's', 'great', 'what', 'a', 'wonderful', 'way', 'to', 'sta', 'the', 'day', 'Like', 'I', 'am', 'athletic', 'Work', 'it', 'girl', 'Woot', 'great', 'job', 'Where', 's', 'rabia', 'at', 'Did', 'I', 'catch', 'up', 'with', 'her', 'what', 'did', 'you', 'do', 'could', 'overlay', 'the', 'temperature', 'as', 'a', 'filter', 'gon', 'na', 'change', 'the', 'interval', 'text', 'to', 'more', 'accurately', 'say', 'that', 'it', 's', 'a', 'Sprint', 'she', 's', 'actually', 'using', 'a', 'competitor', 's', 'app', 'in', 'this', 'photo', 'Oops', 'I', 'think', 'I', 'need', 'to', 'add', 'some', 'more', 'sessions', 'for', 'you', 'now', 'haha', 'Guess', 'not', 'making', 'a', 'ticket', 'now', 'obviously', 'we', 'need', 'a', 'bitmoji', 'integration', 'did', 'you', 'finish', 'the', 'workout', 'post', 'your', 'run', 'bruh', 'I', 'thought', 'you', 'were', 'going', 'to', 'go', 'outside', 'Nice', 'We', 'll', 'add', 'the', 'ability', 'to', 'just', 'order', 'it', 'automatically', 'it', 'was', 'super', 'fun', 'I', 'signed', 'up', 'for', 'classpass', 'and', 'Alice', 'found', 'this', 'gon', 'na', 'use', 'classpass', 'for', 'our', 'weekly', 'fun', 'days', 'yup', 'that', 's', 'the', 'plan', 'Yo', 'do', 'you', 'have', 'a', 'buddy', 'yet', 'Wan', 'na', 'bring', 'Avita', 'in', 'Or', 'someone', 'else', 'A', 'win', 'is', 'a', 'win', 'is', 'a', 'win', 'Small', 'or', 'big', 'And', 'yeah', 'it', 's', 'pretty', 'rough', 'to', 'sta', 'We', 'll', 'eventually', 'modify', 'it', 'so', 'we', 'can', 'detect', 'how', 'well', 'you', 're', 'doing', 'and', 'modify', 'the', 'difficulty', 'dynamically', 'And', 'like', 'Nate', 'said', 'if', 'it', 'was', 'rough', 'that', 'just', 'shows', 'how', 'much', 'potential', 'gain', 'you', 'have', 'by', 'the', 'end', 'of', 'this', 'program', 'hey', 'gurl', 'h ...

# %%
def M(list, words):
  """check if the word is in list of words"""
  L=[]
  for i in list:
    if i not in words:
      pass
    else:
      L.append(i)
  return L

# %%
words_ongo2 = M(words_ongo, words)
words_reddit2 = M(words_reddit, words)
words_tweet2 = M(words_tweet, words)

# %%
words_kaggle2 = M(words_kaggle, words)
words_youtube2 = M(words_youtube, words)

# %%
X_ongo=model_df[words_ongo2] 
X_reddit=model_df[words_reddit2]
X_tweet=model_df[words_tweet2]
X_kaggle=model_df[words_kaggle2]
X_youtube=model_df[words_youtube2]
X_df=model_df[model_df.wv.vocab]
#x_ongo_tweet = model_tweet[model_tweet.wv.vocab]

df_ongo=pd.DataFrame(X_ongo)
df_reddit=pd.DataFrame(X_reddit)
df_tweet=pd.DataFrame(X_tweet)
df_youtube=pd.DataFrame(X_youtube)
df_kaggle=pd.DataFrame(X_kaggle)
df_all = pd.DataFrame(X_df)


#print(df_ongo.head(5))
#df_reddit
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
print(df_reddit.shape, df_kaggle.shape)
# Out:
# (302818, 70) (10617003, 70)

# %%
# Out:
#               0         1         2   ...        67        68        69
# 0      -0.117100  0.723977  0.052122  ... -0.243014 -0.128800  0.014980
# 1      -0.112543  0.103514  0.007941  ... -0.014272  0.001146  0.042729
# 2       0.071675 -0.157223 -0.168090  ...  0.239660  0.077834 -0.093239
# 3       0.012061 -0.006907  0.019246  ...  0.108370  0.038292  0.009061
# 4      -0.016402  0.055619  0.040346  ...  0.025332  0.301512  0.017251
# ...          ...       ...       ...  ...       ...       ...       ...
# 536241       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 536242       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 536243       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 536244       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 536245       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
# [536246 rows x 70 columns]

# %%
np.sum(np.dot(X_reddit,np.linalg.pinv(X_ongo)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-642a7cf211e3> in <module>()
# ----> 1 np.sum(np.dot(X_reddit,np.linalg.pinv(X_ongo)))
#
# NameError: name 'np' is not defined

# %% [markdown]
# Implementing PCA using the numpy library

# %%
#Computing the correlation matrix
X_corr=df_all.corr()


#Computing eigen values and eigen vectors
values,vectors=np.linalg.eig(X_corr)

#Sorting the eigen vectors coresponding to eigen values in descending order
args = (-values).argsort()
values = vectors[args]
vectors = vectors[:, args]


#Taking first 2 components which explain maximum variance for projecting
new_vectors=vectors[:,:2]

#Projecting it onto new dimesion with 2 axis
neww_X=np.dot(X_df,new_vectors)

# %%
#Computing the correlation matrix
X_corr_ongo=df_ongo.corr()
X_corr_reddit=df_reddit.corr()
X_corr_tweet=df_tweet.corr()
X_corr_kaggle=df_kaggle.corr()
X_corr_youtube=df_youtube.corr()

#Computing eigen values and eigen vectors
values_ongo,vectors_ongo=np.linalg.eig(X_corr_ongo)
values_reddit,vectors_reddit=np.linalg.eig(X_corr_reddit)
values_tweet,vectors_tweet=np.linalg.eig(X_corr_tweet)
values_kaggle,vectors_kaggle=np.linalg.eig(X_corr_kaggle)
values_youtube,vectors_youtube=np.linalg.eig(X_corr_youtube)

#Sorting the eigen vectors coresponding to eigen values in descending order
args_ongo = (-values_ongo).argsort()
values_ongo = vectors_ongo[args_ongo]
vectors_ongo = vectors_ongo[:, args_ongo]

args_reddit = (-values_reddit).argsort()
values_reddit = vectors_reddit[args_reddit]
vectors_reddit = vectors_reddit[:, args_reddit]

args_tweet = (-values_tweet).argsort()
values_tweet = vectors_tweet[args_tweet]
vectors_tweet = vectors_tweet[:, args_tweet]

args_kaggle = (-values_kaggle).argsort()
values_kaggle = vectors_kaggle[args_kaggle]
vectors_kaggle = vectors_kaggle[:, args_kaggle]

args_youtube = (-values_youtube).argsort()
values_youtube = vectors_youtube[args_youtube]
vectors_youtube = vectors_youtube[:, args_youtube]
#Taking first 2 components which explain maximum variance for projecting
new_vectors_ongo=vectors_ongo[:,:2]
new_vectors_reddit=vectors_reddit[:,:2]
new_vectors_tweet=vectors_tweet[:,:2]
new_vectors_kaggle=vectors_kaggle[:,:2]
new_vectors_youtube=vectors_youtube[:,:2]

#Projecting it onto new dimesion with 2 axis
neww_X_ongo=np.dot(X_ongo,new_vectors_ongo)
neww_X_reddit=np.dot(X_reddit,new_vectors_reddit)
neww_X_tweet=np.dot(X_tweet,new_vectors_tweet)
neww_X_kaggle=np.dot(X_kaggle,new_vectors_kaggle)
neww_X_youtube=np.dot(X_youtube,new_vectors_youtube)

# %%
print(words_ongo)
# Out:
# ['Hello', 'Got', 'ta', 'get', 'those', 'zzzs', 'go', 'go', 'ongo', 'go', 'Hey', 'can', 'not', 'wait', 'to', 'release', 'the', 'new', 'version', 'Newsfeed', 'should', 'get', 'come', 'alive', 'with', 'photos', 'Good', 'job', 'Hahaha', 'finding', 'bugs', 'is', 'progress', 'That', 's', 'a', 'scenic', 'workout', 'spot', 'lol', 'That', 'looks', 'fun', 'That', 's', 'a', 'really', 'good', 'idea', 'Whoa', 'That', 's', 'awesome', 'guys', 'Yeah', 'I', 'decided', 'to', 'run', 'and', 'do', 'some', 'strength', 'training', 'for', 'fun', 'day', 'Oooh', 'nice', 'Looks', 'like', 'we', 'found', 'another', 'bug', 'Nice', 'Keep', 'it', 'going', 'Wow', 'nice', 'that', 's', 'awesome', 'Almost', 'there', 'Nice', 'gainz', 'adding', 'a', 'new', 'comment', 'Got', 'ta', 'get', 'those', 'gainz', 'Yeah', 'I', 'usually', 'dread', 'them', 'but', 'it', 's', 'not', 'so', 'bad', 'if', 'you', 're', 'only', 'doing', 'it', 'for', 'seconds', 'I', 'm', 'savoring', 'the', 'last', 'sessions', 'of', 'this', 'program', 'She', 's', 'really', 'good', 'Dang', 'Woot', 'and', 'Daft', 'Punk', 'comes', 'on', 'Hi', 'Christine', 'welcome', 'to', 'Ongo', 'Welcome', 'Yu', 'kai', 'Nice', 'run', 'Abhi', 'Great', 'feedback', 'on', 'the', 'treadmill', 'we', 'll', 'try', 'to', 'improve', 'that', 'experience', 'That', 's', 'awesome', 'W00t', 'sup', 'oh', 'didnot', 'realize', 'this', 'was', 'a', 'user', 'posted', 'picture', 'looks', 'so', 'purdy', 'NSFW', 'yes', 'lol', 'and', 'be', 'able', 'to', 'add', 'taunt', 'another', 'person', 'through', 'bitmoji', 'I', 'did', 'finish', 'but', 'wasnot', 'given', 'the', 'option', 'to', 'post', 'my', 'run', 'i', 'was', 'but', 'then', 'I', 'just', 'went', 'to', 'the', 'gym', 'so', 'I', 'could', 'also', 'lift', 'weights', 'that', 'would', 'be', 'perfect', 'apron', 'style', 'before', 'sessions', 'tell', 'me', 'what', 'things', 'I', 'need', 'and', 'give', 'me', 'the', 'option', 'to', 'order', 'them', 'or', 'make', 'sure', 'I', 'have', 'them', '1', 'manny', 'liked', 'your', 'comment', 'yeah', 'walk', 'and', 'run', 'every', 'seconds', 'was', 'a', 'killer', 'but', 'felt', 'good', 'after', 'what', 'headphones', 'are', 'you', 'using', 'for', 'your', 'runs', 'actually', 'it', 'was', 'really', 'nice', 'Fat', 'Burner', 'Wow', 'that', 's', 'great', 'what', 'a', 'wonderful', 'way', 'to', 'sta', 'the', 'day', 'Like', 'I', 'am', 'athletic', 'Work', 'it', 'girl', 'Woot', 'great', 'job', 'Where', 's', 'rabia', 'at', 'Did', 'I', 'catch', 'up', 'with', 'her', 'what', 'did', 'you', 'do', 'could', 'overlay', 'the', 'temperature', 'as', 'a', 'filter', 'gon', 'na', 'change', 'the', 'interval', 'text', 'to', 'more', 'accurately', 'say', 'that', 'it', 's', 'a', 'Sprint', 'she', 's', 'actually', 'using', 'a', 'competitor', 's', 'app', 'in', 'this', 'photo', 'Oops', 'I', 'think', 'I', 'need', 'to', 'add', 'some', 'more', 'sessions', 'for', 'you', 'now', 'haha', 'Guess', 'not', 'making', 'a', 'ticket', 'now', 'obviously', 'we', 'need', 'a', 'bitmoji', 'integration', 'did', 'you', 'finish', 'the', 'workout', 'post', 'your', 'run', 'bruh', 'I', 'thought', 'you', 'were', 'going', 'to', 'go', 'outside', 'Nice', 'We', 'll', 'add', 'the', 'ability', 'to', 'just', 'order', 'it', 'automatically', 'it', 'was', 'super', 'fun', 'I', 'signed', 'up', 'for', 'classpass', 'and', 'Alice', 'found', 'this', 'gon', 'na', 'use', 'classpass', 'for', 'our', 'weekly', 'fun', 'days', 'yup', 'that', 's', 'the', 'plan', 'Yo', 'do', 'you', 'have', 'a', 'buddy', 'yet', 'Wan', 'na', 'bring', 'Avita', 'in', 'Or', 'someone', 'else', 'A', 'win', 'is', 'a', 'win', 'is', 'a', 'win', 'Small', 'or', 'big', 'And', 'yeah', 'it', 's', 'pretty', 'rough', 'to', 'sta', 'We', 'll', 'eventually', 'modify', 'it', 'so', 'we', 'can', 'detect', 'how', 'well', 'you', 're', 'doing', 'and', 'modify', 'the', 'difficulty', 'dynamically', 'And', 'like', 'Nate', 'said', 'if', 'it', 'was', 'rough', 'that', 'just', 'shows', 'how', 'much', 'potential', 'gain', 'you', 'have', 'by', 'the', 'end', 'of', 'this', 'program', 'hey', 'gurl', 'h ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(13,7))
plt.scatter(neww_X_kaggle[:,0],neww_X_kaggle[:,1],linewidths=10,color='black', alpha=0.6)
plt.scatter(neww_X_reddit[:,0],neww_X_reddit[:,1],linewidths=10,color='crimson', alpha=0.8)
plt.scatter(neww_X_tweet[:,0],neww_X_tweet[:,1],linewidths=10,color='teal',alpha=0.9)
plt.scatter(neww_X_ongo[:,0],neww_X_ongo[:,1],linewidths=10,color='gold',alpha=0.5)
#plt.scatter(neww_X_youtube[:,0],neww_X_youtube[:,1],linewidths=10,color='blue',alpha=0.5)
plt.xlabel("PC1",size=15)
plt.ylabel("PC2",size=15)
plt.legend(['kaggle','reddit','twitter', 'ongo'], loc=3,prop={'size': 15}) 
plt.title("Word Embedding Space",size=20)
#vocab=list(model_df.wv.vocab)

for i, word in enumerate(words_reddit2):
  if word in words:
    if neww_X_reddit[i,1] <-2 or neww_X_reddit[i,0]>1:
      plt.annotate(word,xy=(neww_X_reddit[i,0],neww_X_reddit[i,1]))
"""
for i, word in enumerate(words_tweet2):
  if word in words:
    if neww_X_tweet[i,0] >2.5:
        plt.annotate(word,xy=(neww_X_tweet[i,0],neww_X_tweet[i,1]))
for i, word in enumerate(words_kaggle2):
  if word in words:
    if neww_X_kaggle[i,0]<-4:
        plt.annotate(word,xy=(neww_X_kaggle[i,0],neww_X_kaggle[i,1]))

for i, word in enumerate(words_kaggle2):
  if word in words:
    if neww_X_kaggle[i,0]<-4:
        plt.annotate(word,xy=(neww_X_kaggle[i,0],neww_X_kaggle[i,1]))"""
# Out:
# '\nfor i, word in enumerate(words_tweet2):\n  if word in words:\n    if neww_X_tweet[i,0] >2.5:\n        plt.annotate(word,xy=(neww_X_tweet[i,0],neww_X_tweet[i,1]))\nfor i, word in enumerate(words_kaggle2):\n  if word in words:\n    if neww_X_kaggle[i,0]<-4:\n        plt.annotate(word,xy=(neww_X_kaggle[i,0],neww_X_kaggle[i,1]))\n\nfor i, word in enumerate(words_kaggle2):\n  if word in words:\n    if neww_X_kaggle[i,0]<-4:\n        plt.annotate(word,xy=(neww_X_kaggle[i,0],neww_X_kaggle[i,1]))'

# %%
from sklearn.metrics.pairwise import cosine_similarity
def get_cosine_similarity(feature_vec_1, feature_vec_2):    
    return cosine_similarity(feature_vec_1.reshape(1, -1), feature_vec_2.reshape(1, -1))[0][0]

# %%
vectors_reddit.shape
# Out:
# (70, 70)

# %%
get_cosine_similarity(X_kaggle,X_ongo)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-ad8d695816f9> in <module>()
# ----> 1 get_cosine_similarity(X_kaggle,X_ongo)
#
# <ipython-input-54-50fa871c4336> in get_cosine_similarity(feature_vec_1, feature_vec_2)
#       1 from sklearn.metrics.pairwise import cosine_similarity
#       2 def get_cosine_similarity(feature_vec_1, feature_vec_2):
# ----> 3     return cosine_similarity(feature_vec_1.reshape(1, -1), feature_vec_2.reshape(1, -1))[0][0]
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/pairwise.py in cosine_similarity(X, Y, dense_output)
#    1165     # to avoid recursive import
#    1166
# -> 1167     X, Y = check_pairwise_arrays(X, Y)
#    1168
#    1169     X_normalized = normalize(X, copy=True)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     153         raise ValueError("Incompatible dimension for X and Y matrices: "
#     154                          "X.shape[1] == %d while Y.shape[1] == %d" % (
# --> 155                              X.shape[1], Y.shape[1]))
#     156
#     157     return X, Y
#
# ValueError: Incompatible dimension for X and Y matrices: X.shape[1] == 743191750 while Y.shape[1] == 13234200

# %%
get_cosine_similarity(vectors_youtube,vectors_ongo)
# Out:
# -0.012663514746061508

# %%
df
# Out:
#              0         1         2   ...        67        68        69
# 0     -0.017326 -0.289433  0.219794  ... -0.430161  0.639327  0.841878
# 1     -0.340207 -0.397933 -0.566564  ... -0.189859  0.639780  0.444826
# 2     -0.145351 -0.905047 -1.014651  ... -0.426298  0.658032  0.217779
# 3     -0.454908 -0.004154 -0.296913  ...  0.363327  0.406718  0.284796
# 4     -0.290996  0.140046 -0.171693  ...  0.421158  0.069362  0.270477
# ...         ...       ...       ...  ...       ...       ...       ...
# 82512 -0.010539 -0.022247 -0.079349  ...  0.022423  0.249499  0.204330
# 82513 -0.124976  0.077138 -0.092842  ... -0.005664  0.191574  0.246866
# 82514  0.026729  0.067528 -0.093735  ...  0.027102  0.153408  0.240908
# 82515 -0.017944 -0.001495 -0.142752  ... -0.003789  0.162803  0.196552
# 82516 -0.083831  0.063891  0.036753  ... -0.037055  0.192330  0.167813
#
# [82517 rows x 70 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(13,7))
#plt.scatter(neww_X[:,0],neww_X[:,1],linewidths=10,color='blue')
#plt.scatter(neww_X_reddit[:,0],neww_X_reddit[:,1],linewidths=10,color='red')
#plt.scatter(neww_X_tweet[:,0],neww_X_tweet[:,1],linewidths=10,color='teal')
plt.xlabel("PC1",size=15)
plt.ylabel("PC2",size=15)
plt.title("Word Embedding Space",size=20)
vocab=list(model_df.wv.vocab)
#for i, word in enumerate(vocab):
#  plt.annotate(word,xy=(neww_X[i,0],neww_X[i,1]))
groups = df2.groupby("source")
for name, group in groups:
    plt.plot(group[neww_X[:,0]], group[neww_X[:,0]], marker="o", linestyle="", label=name)
plt.legend()
for i, word in enumerate(vocab_tweet):
  if word == 'shit':
      plt.annotate(word,xy=(neww_X_tweet[i,0],neww_X_tweet[i,1]))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,12))
plt.scatter(neww_X_reddit[:,0],neww_X_reddit[:,1],linewidths=10,color='crimson', alpha=0.8)
plt.scatter(neww_X_tweet[:,0],neww_X_tweet[:,1],linewidths=10,color='teal',alpha=0.7)
#plt.scatter(neww_X_kaggle[:,0],neww_X_kaggle[:,1],linewidths=10,color='gold', alpha=0.5)
plt.scatter(neww_X_ongo[:,0],neww_X_ongo[:,1],linewidths=10,color='gold',alpha=0.7)

plt.xlabel("PC1",size=15)
plt.ylabel("PC2",size=15)
plt.title("Word Embedding Space",size=20)
plt.legend(['ongo','reddit','tweet', 'kaggle'], loc=2,prop={'size': 15}) 
vocab=list(model_kaggle.wv.vocab)
vocab_tweet=list(model_tweet.wv.vocab)
vocab_reddit=list(model_reddit.wv.vocab)

#for i, word in enumerate(vocab):
#  if word == 'shit':
#      plt.annotate(word,xy=(neww_X_kaggle[i,0],neww_X_kaggle[i,1]))

for i, word in enumerate(vocab_reddit):
  if word == 'shit':
      plt.annotate(word,xy=(neww_X_reddit[i,0],neww_X_reddit[i,1]))


for i, word in enumerate(vocab_tweet):
  if word == 'shit':
      plt.annotate(word,xy=(neww_X_tweet[i,0],neww_X_tweet[i,1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-5472e2ead35e> in <module>()
#      10 plt.title("Word Embedding Space",size=20)
#      11 plt.legend(['ongo','reddit','tweet', 'kaggle'], loc=2,prop={'size': 15})
# ---> 12 vocab=list(model_kaggle.wv.vocab)
#      13 vocab_tweet=list(model_tweet.wv.vocab)
#      14 vocab_reddit=list(model_reddit.wv.vocab)
#
# NameError: name 'model_kaggle' is not defined
